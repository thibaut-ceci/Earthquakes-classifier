# %% [markdown]
# # Remove useless pickle
#
# Here, we want to remove events without pickle file

# %%
from tqdm.notebook import tqdm

import catalog
import cleaning

tqdm.pandas()
catalog.display_parameters()

# %% [markdown]
# ## Load the database

# %%
dataframe = catalog.load("data/new_dataframe_with_inventory.pickle")

catalog.open_plot(dataframe, pos_number=0.05, xlim=26000)

# %% [markdown]
# ## Remove the events without pickle file

# %%
dataframe = cleaning.events_without_pickle_file(dataframe)
# Out:
#   0%|          | 0/23159 [00:00<?, ?it/s]
# In this catalog, there are now 12682 avalanches.

# %% [markdown]
# ## Save the new database

# %%
dataframe.to_pickle("data/new_dataframe_with_inventory_cleaned.pickle")
