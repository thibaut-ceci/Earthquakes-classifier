# %%
import pandas as pd

import catalog

catalog.display_parameters()

# %%
EQ = pd.read_csv("data/query.csv")
NONEQ = pd.read_csv("data/NONEQ.csv")

# %%
catalog.open_plot(EQ, pos_number=0.15, xlim=1200)

# %%
catalog.open_plot(NONEQ, pos_number=0.15, xlim=21000)
