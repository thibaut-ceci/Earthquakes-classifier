# %% [markdown]
# # Clean the database
# Here, we will remove useless columns in the new database

# %%
import catalog

catalog.display_parameters()

# %% [markdown]
# ## First, load the new database

# %%
dataframe = catalog.load("data/new_database.pickle")

# %% [markdown]
# ## Distribution of columns

# %%
catalog.open_plot(dataframe, pos_number=0.12, xlim=26000)

# %% [markdown]
# ## Removing useless columns
#
# Many columns are not useful in this study. Let's remove them :

# %%
colonne = ['depth', 'nst', 'gap', 'dmin', 'rms', 'net', 'magType', 'id', 'horizontalError', 'depthError', 'magError', 'magNst', 'locationSource', 'magSource', 'updated', 'status']
dataframe.drop(colonne, axis=1, inplace=True)

# %% [markdown]
# We will need only the time, the localisation (longitude, latitude and the place), the type and the magnitude of the events.

# %%
catalog.open_plot(dataframe, pos_number=0.035, xlim=26000)

dataframe.to_pickle("data/new_database.pickle")
